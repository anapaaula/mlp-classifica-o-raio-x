# %% [markdown]
# <a href="https://colab.research.google.com/github/anapaaula/mlp-raio-x/blob/main/Projeto_Classifica%C3%A7%C3%A3o_de_Raio_X_com_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classificação de Raio X

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### Importando os dados

# %% [markdown]
# O objetivo deste projeto é desenvolver um Multi-Layer Perceptron capaz de classificar imagens de Raio-X Torácico em duas categorias: NORMAL ou PNEUMONIA. A proposta envolve a construção de um classificador eficiente, utilizando imagens médicas para auxiliar no diagnóstico de pneumonia com base em padrões visuais extraídos dos exames de Raio-X.
#
# As imagens utilizadas no projeto estão disponíveis aqui: [link](https://drive.google.com/drive/folders/1dkmO4y-vzo1SS7cmbT-CumymqUfPWlrf?usp=sharing)
#
# As imagens foram convertidas em formato de vetores numéricos, e podem ser acessadas diretamente através dos arquivos CSV: [treino](https://drive.google.com/file/d/1p8QQIfkCQxjS1sSR-xtIU5qXsqcXqsPQ/view?usp=sharing) e [teste](https://drive.google.com/file/d/1K0eu-4H28VocKWKyZcT9enSx9vJM0R7Q/view?usp=sharing).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path_train = '/content/drive/MyDrive/CDP/x_ray_train.csv'
df_train = pd.read_csv(file_path_train)

# %%
file_path_test = '/content/drive/MyDrive/CDP/x_ray_test.csv'
df_test = pd.read_csv(file_path_test)

# %%
df_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.043137  0.117647  0.078431  0.047059  0.050980  0.203922  0.274510
# 1  0.427451  0.474510  0.435294  0.329412  0.360784  0.372549  0.368627
# 2  0.403922  0.325490  0.341176  0.360784  0.337255  0.317647  0.329412
# 3  0.294118  0.313725  0.305882  0.325490  0.364706  0.403922  0.533333
# 4  0.007843  0.117647  0.301961  0.400000  0.556863  0.541176  0.490196
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.372549  0.470588  0.529412  ...  0.552941  0.525490  0.482353  0.439216
# 1  0.400000  0.419608  0.345098  ...  0.760784  0.733333  0.701961  0.662745
# 2  0.419608  0.549020  0.588235  ...  0.737255  0.705882  0.682353  0.666667
# 3  0.423529  0.380392  0.380392  ...  0.592157  0.568627  0.549020  0.521569
# 4  0.482353  0.537255  0.462745  ...  0.505882  0.509804  0.627451  0.572549
#
#         779       780       781       782       783  label
# 0  0.352941  0.211765  0.050980  0.066667  0.066667      1
# 1  0.596078  0.529412  0.176471  0.086275  0.188235      1
# 2  0.650980  0.607843  0.533333  0.196078  0.015686      1
# 3  0.486275  0.462745  0.431373  0.443137  0.407843      1
# 4  0.454902  0.564706  0.474510  0.062745  0.000000      1
#
# [5 rows x 785 columns]

# %%
df_test.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.145098  0.207843  0.392157  0.396078  0.349020  0.372549  0.356863
# 1  0.050980  0.207843  0.368627  0.454902  0.415686  0.431373  0.490196
# 2  0.207843  0.227451  0.333333  0.223529  0.247059  0.219608  0.196078
# 3  0.529412  0.333333  0.282353  0.149020  0.176471  0.196078  0.168627
# 4  0.007843  0.082353  0.168627  0.133333  0.105882  0.105882  0.129412
#
#           7         8         9  ...       775       776       777       778  \
# 0  0.368627  0.517647  0.678431  ...  0.674510  0.686275  0.674510  0.627451
# 1  0.517647  0.490196  0.588235  ...  0.835294  0.788235  0.768627  0.752941
# 2  0.321569  0.396078  0.349020  ...  0.623529  0.607843  0.588235  0.607843
# 3  0.152941  0.231373  0.196078  ...  0.545098  0.494118  0.439216  0.376471
# 4  0.184314  0.290196  0.482353  ...  0.866667  0.847059  0.827451  0.772549
#
#         779       780       781       782       783  label
# 0  0.580392  0.521569  0.458824  0.423529  0.164706      1
# 1  0.713725  0.654902  0.356863  0.000000  0.000000      1
# 2  0.533333  0.443137  0.192157  0.070588  0.105882      1
# 3  0.305882  0.439216  0.047059  0.043137  0.058824      1
# 4  0.760784  0.427451  0.098039  0.117647  0.011765      0
#
# [5 rows x 785 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5234 entries, 0 to 5233
# Columns: 785 entries, 0 to label
# dtypes: float64(784), int64(1)
# memory usage: 31.3 MB

# %%
df_train.describe()
# Out:
#                  0            1            2            3            4  \
# count  5234.000000  5234.000000  5234.000000  5234.000000  5234.000000
# mean      0.224090     0.285522     0.327118     0.336399     0.349791
# std       0.183808     0.165954     0.161803     0.171717     0.178899
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.078431     0.172549     0.223529     0.215686     0.219608
# 50%       0.192157     0.274510     0.321569     0.329412     0.345098
# 75%       0.325490     0.384314     0.431373     0.462745     0.482353
# max       0.941176     0.917647     0.937255     0.929412     0.952941
#
#                  5            6            7            8            9  ...  \
# count  5234.000000  5234.000000  5234.000000  5234.000000  5234.000000  ...
# mean      0.357629     0.368767     0.392606     0.438370     0.500947  ...
# std       0.185078     0.195747     0.206407     0.210975     0.200511  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.223529     0.223529     0.239216     0.286275     0.360784  ...
# 50%       0.356863     0.372549     0.400000     0.454902     0.523529  ...
# 75%       0.498039     0.513725     0.556863     0.607843     0.654902  ...
# max       0.933333     0.980392     0.960784     0.992157     0.960784  ...
#
#                775          776          777          778          779  \
# count  5234.000000  5234.000000  5234.000000  5234.000000  5234.000000
# mean      0.693873     0.677663     0.657491     0.629152     0.579572
# std       0.119645     0.122030     0.124553     0.132123     0.155744
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.635294     0.615686     0.592157     0.560784     0.501961
# 50%       0.713725     0.698039     0.682353     0.650980     0.607843
# 75%       0.772549     0.760784     0.745098     0.725490     0.690196
# max       0.992157     0.976471     0.941176     0.945098     0.952941
#
#                780          781          782          783        label
# count  5234.000000  5234.000000  5234.000000  5234.000000  5234.000000
# mean      0.479711     0.313809     0.151523     0.083151     0.741880
# std       0.198200     0.216578     0.166743     0.121439     0.437642
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.360784     0.109804     0.019608     0.000000     0.000000
# 50%       0.525490     0.305882     0.094118     0.039216     1.000000
# 75%       0.627451     0.498039     0.227451     0.113725     1.000000
# max       0.972549     0.984314     0.886275     1.000000     1.000000
#
# [8 rows x 785 columns]

# %%
df_train.isna().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 780      0
# 781      0
# 782      0
# 783      0
# label    0
# Length: 785, dtype: int64

# %% [markdown]
# ### Balanceando os dados

# %%
x_train, y_train = df_train.drop(columns=["label"]), df_train["label"]

# %%
x_test, y_test = df_test.drop(columns=["label"]), df_test["label"]

# %%
print(y_train.value_counts())
# Out:
# label
# 1    3883
# 0    1351
# Name: count, dtype: int64

# %% [markdown]
# Os dados de treino apresentam um desbalanceamento significativo na variável de saída (label), com uma quantidade maior de ocorrências do valor 1 (indicando pneumonia) em comparação com o valor 0 (indicando ausência de pneumonia). Esse desbalanceamento pode resultar em um viés do modelo a favor da classe majoritária, prejudicando sua capacidade de detectar corretamente a classe minoritária.
#
# Para mitigar esse problema e garantir que o modelo classifique ambas as classes de forma equilibrada, será aplicada a técnica SMOTE (Synthetic Minority Over-sampling Technique). O SMOTE cria novas instâncias sintéticas da classe minoritária, balanceando os dados de entrada e reduzindo o risco de viés durante o treinamento.

# %%
smote = SMOTE()
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# %%
print(y_train_balanced.value_counts())
# Out:
# label
# 1    3883
# 0    3883
# Name: count, dtype: int64

# %% [markdown]
# ## Treinando MLPs

# %% [markdown]
# Serão treinados três modelos com as seguintes configurações:
#
# * Modelo 1: Uma camada oculta com 50 neurônios, utilizando a função de ativação logistic (sigmóide).
#
# * Modelo 2: Duas camadas ocultas, com 50 neurônios na primeira camada e 25 neurônios na segunda, utilizando a função de ativação ReLU.
#
# * Modelo 3: Três camadas ocultas, com 50 neurônios na primeira camada, 25 neurônios na segunda e 13 neurônios na terceira, utilizando a função de ativação tanh.

# %% [markdown]
# ### Modelo 1

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50), activation='logistic', max_iter=500, verbose = True)
mlp.fit(x_train_balanced, y_train_balanced)
y_pred = mlp.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Iteration 1, loss = 0.60142318
# Iteration 2, loss = 0.43074087
# Iteration 3, loss = 0.32482165
# Iteration 4, loss = 0.26327788
# Iteration 5, loss = 0.22262926
# Iteration 6, loss = 0.19431250
# Iteration 7, loss = 0.17405242
# Iteration 8, loss = 0.16277690
# Iteration 9, loss = 0.14799245
# Iteration 10, loss = 0.14265007
# Iteration 11, loss = 0.13452570
# Iteration 12, loss = 0.12946276
# Iteration 13, loss = 0.12460468
# Iteration 14, loss = 0.12350514
# Iteration 15, loss = 0.12067226
# Iteration 16, loss = 0.11742632
# Iteration 17, loss = 0.11549560
# Iteration 18, loss = 0.11420150
# Iteration 19, loss = 0.11346591
# Iteration 20, loss = 0.11083935
# Iteration 21, loss = 0.10913015
# Iteration 22, loss = 0.10732810
# Iteration 23, loss = 0.10763223
# Iteration 24, loss = 0.10495503
# Iteration 25, loss = 0.10420122
# Iteration 26, loss = 0.10625244
# Iteration 27, loss = 0.10756828
# Iteration 28, loss = 0.10754508
# Iteration 29, loss = 0.10489851
# Iteration 30, loss = 0.11059751
# Iteration 31, loss = 0.10257199
# Iteration 32, loss = 0.10118304
# Iteration 33, loss = 0.10096006
# Iteration 34, loss = 0.10111041
# Iteration 35, loss = 0.09827161
# Iteration 36, loss = 0.09745020
# Iteration 37, loss = 0.09870887
# Iteration 38, loss = 0.09638145
# Iteration 39, loss = 0.09760553
# Iteration 40, loss = 0.09471538
# Iteration 41, loss = 0.09586139
# Iteration 42, loss = 0.09440781
# Iteration 43, loss = 0.09440298
# Iteration 44, loss = 0.09183557
# Iteration 45, loss = 0.09513262
# Iteration 46, loss = 0.09430337
# Iteration 47, loss = 0.09179127
# Iteration 48, loss = 0.09394471
# Iteration 49, loss = 0.09180346
# Iteration 50, loss = 0.09059846
# Iteration 51, loss = 0.09068545
# Iteration 52, loss = 0.08894383
# Iteration 53, loss = 0.09110626
# Iteration 54, loss = 0.09026257
# Iteration 55, loss = 0.09054795
# Iteration 56, loss = 0.09106556
# Iteration 57, loss = 0.08741563
# Iteration 58, loss = 0.08756620
# Iteration 59, loss = 0.08648587
# Iteration 60, loss = 0.08688255
# Iteration 61, loss = 0.08573189
# Iteration 62, loss = 0.08562760
# Iteration 63, loss = 0.08981379
# Iteration 64, loss = 0.09586919
# Iteration 65, loss = 0.08570231
# Iteration 66, loss = 0.08774494
# Iteration 67, loss = 0.08859115
# Iteration 68, loss = 0.08382043
# Iteration 69, loss = 0.08340511
# Iteration 70, loss = 0.08824208
# Iteration 71, loss = 0.08378191
# Iteration 72, loss = 0.08176667
# Iteration 73, loss = 0.08161937
# Iteration 74, loss = 0.08655699
# Iteration 75, loss = 0.08323437
# Iteration 76, loss = 0.08239681
# Iteration 77, loss = 0.08610018
# Iteration 78, loss = 0.08264639
# Iteration 79, loss = 0.07932499
# Iteration 80, loss = 0.08082155
# Iteration 81, loss = 0.07925860
# Iteration 82, loss = 0.08036433
# Iteration 83, loss = 0.08330948
# Iteration 84, loss = 0.07962976
# Iteration 85, loss = 0.07752854
# Iteration 86, loss = 0.07714965
# Iteration 87, loss = 0.07752516
# Iteration 88, loss = 0.07652355
# Iteration 89, loss = 0.07760153
# Iteration 90, loss = 0.07633590
# Iteration 91, loss = 0.07498784
# Iteration 92, loss = 0.07489510
# Iteration 93, loss = 0.07761027
# Iteration 94, loss = 0.07535735
# Iteration 95, loss = 0.07375480
# Iteration 96, loss = 0.07490960
# Iteration 97, loss = 0.07728240
# Iteration 98, loss = 0.07954722
# Iteration 99, loss = 0.07797728
# Iteration 100, loss = 0.07764302
# Iteration 101, loss = 0.07382246
# Iteration 102, loss = 0.07346265
# Iteration 103, loss = 0.07237867
# Iteration 104, loss = 0.07528494
# Iteration 105, loss = 0.07499291
# Iteration 106, loss = 0.07003691
# Iteration 107, loss = 0.06903453
# Iteration 108, loss = 0.07181356
# Iteration 109, loss = 0.06948811
# Iteration 110, loss = 0.06961935
# Iteration 111, loss = 0.07614941
# Iteration 112, loss = 0.06748292
# Iteration 113, loss = 0.06746740
# Iteration 114, loss = 0.06839472
# Iteration 115, loss = 0.06822290
# Iteration 116, loss = 0.06814947
# Iteration 117, loss = 0.07257781
# Iteration 118, loss = 0.06731012
# Iteration 119, loss = 0.06730903
# Iteration 120, loss = 0.06604700
# Iteration 121, loss = 0.06458733
# Iteration 122, loss = 0.06647618
# Iteration 123, loss = 0.06512019
# Iteration 124, loss = 0.06774005
# Iteration 125, loss = 0.06446878
# Iteration 126, loss = 0.06762046
# Iteration 127, loss = 0.06522998
# Iteration 128, loss = 0.07265850
# Iteration 129, loss = 0.06390704
# Iteration 130, loss = 0.06366934
# Iteration 131, loss = 0.07702869
# Iteration 132, loss = 0.06382181
# Iteration 133, loss = 0.06208169
# Iteration 134, loss = 0.06291606
# Iteration 135, loss = 0.06073492
# Iteration 136, loss = 0.06024681
# Iteration 137, loss = 0.06325185
# Iteration 138, loss = 0.06369903
# Iteration 139, loss = 0.06181257
# Iteration 140, loss = 0.06037759
# Iteration 141, loss = 0.05920831
# Iteration 142, loss = 0.05949010
# Iteration 143, loss = 0.05833319
# Iteration 144, loss = 0.06012804
# Iteration 145, loss = 0.06014407
# Iteration 146, loss = 0.06139765
# Iteration 147, loss = 0.06146305
# Iteration 148, loss = 0.05817229
# Iteration 149, loss = 0.05707561
# Iteration 150, loss = 0.05708846
# Iteration 151, loss = 0.05755313
# Iteration 152, loss = 0.06323556
# Iteration 153, loss = 0.05678162
# Iteration 154, loss = 0.05698989
# Iteration 155, loss = 0.05606664
# Iteration 156, loss = 0.05472603
# Iteration 157, loss = 0.05652464
# Iteration 158, loss = 0.05458635
# Iteration 159, loss = 0.05847836
# Iteration 160, loss = 0.05629198
# Iteration 161, loss = 0.05600730
# Iteration 162, loss = 0.05396650
# Iteration 163, loss = 0.05645298
# Iteration 164, loss = 0.05272332
# Iteration 165, loss = 0.05242734
# Iteration 166, loss = 0.05745462
# Iteration 167, loss = 0.05417614
# Iteration 168, loss = 0.05600529
# Iteration 169, loss = 0.05312917
# Iteration 170, loss = 0.05245150
# Iteration 171, loss = 0.05195651
# Iteration 172, loss = 0.05143687
# Iteration 173, loss = 0.05528605
# Iteration 174, loss = 0.04982920
# Iteration 175, loss = 0.05198018
# Iteration 176, loss = 0.05020647
# Iteration 177, loss = 0.05136612
# Iteration 178, loss = 0.05259989
# Iteration 179, loss = 0.05567163
# Iteration 180, loss = 0.05230715
# Iteration 181, loss = 0.04855149
# Iteration 182, loss = 0.04919572
# Iteration 183, loss = 0.04953093
# Iteration 184, loss = 0.04967509
# Iteration 185, loss = 0.04764447
# Iteration 186, loss = 0.04793928
# Iteration 187, loss = 0.04758769
# Iteration 188, loss = 0.04781390
# Iteration 189, loss = 0.04766643
# Iteration 190, loss = 0.04810520
# Iteration 191, loss = 0.04799323
# Iteration 192, loss = 0.05184942
# Iteration 193, loss = 0.04622216
# Iteration 194, loss = 0.04931625
# Iteration 195, loss = 0.04713549
# Iteration 196, loss = 0.04524661
# Iteration 197, loss = 0.04684793
# Iteration 198, loss = 0.04964450
# Iteration 199, loss = 0.04676834
# Iteration 200, loss = 0.04477631
# Iteration 201, loss = 0.04791601
# Iteration 202, loss = 0.04638972
# Iteration 203, loss = 0.05054590
# Iteration 204, loss = 0.04510469
# Iteration 205, loss = 0.04608448
# Iteration 206, loss = 0.04423792
# Iteration 207, loss = 0.04475692
# Iteration 208, loss = 0.04595610
# Iteration 209, loss = 0.04418209
# Iteration 210, loss = 0.04399661
# Iteration 211, loss = 0.04267769
# Iteration 212, loss = 0.04591633
# Iteration 213, loss = 0.04366200
# Iteration 214, loss = 0.04273380
# Iteration 215, loss = 0.04781077
# Iteration 216, loss = 0.04970456
# Iteration 217, loss = 0.04101789
# Iteration 218, loss = 0.04557325
# Iteration 219, loss = 0.04513333
# Iteration 220, loss = 0.04284499
# Iteration 221, loss = 0.04027197
# Iteration 222, loss = 0.03955825
# Iteration 223, loss = 0.04289347
# Iteration 224, loss = 0.04249603
# Iteration 225, loss = 0.04084465
# Iteration 226, loss = 0.03873383
# Iteration 227, loss = 0.03871921
# Iteration 228, loss = 0.03826757
# Iteration 229, loss = 0.03969131
# Iteration 230, loss = 0.04280113
# Iteration 231, loss = 0.03760630
# Iteration 232, loss = 0.03795346
# Iteration 233, loss = 0.04137144
# Iteration 234, loss = 0.03766030
# Iteration 235, loss = 0.03859145
# Iteration 236, loss = 0.04070566
# Iteration 237, loss = 0.03946193
# Iteration 238, loss = 0.03748096
# Iteration 239, loss = 0.04118263
# Iteration 240, loss = 0.04217768
# Iteration 241, loss = 0.03892690
# Iteration 242, loss = 0.04771439
# Iteration 243, loss = 0.04022833
# Iteration 244, loss = 0.03695875
# Iteration 245, loss = 0.03663172
# Iteration 246, loss = 0.03853955
# Iteration 247, loss = 0.03539302
# Iteration 248, loss = 0.03534914
# Iteration 249, loss = 0.03619307
# Iteration 250, loss = 0.03584494
# Iteration 251, loss = 0.03938765
# Iteration 252, loss = 0.03428705
# Iteration 253, loss = 0.03489623
# Iteration 254, loss = 0.03379180
# Iteration 255, loss = 0.03472415
# Iteration 256, loss = 0.03380156
# Iteration 257, loss = 0.03437927
# Iteration 258, loss = 0.03779220
# Iteration 259, loss = 0.03315062
# Iteration 260, loss = 0.03432983
# Iteration 261, loss = 0.03415559
# Iteration 262, loss = 0.03673257
# Iteration 263, loss = 0.03412116
# Iteration 264, loss = 0.03817938
# Iteration 265, loss = 0.03399332
# Iteration 266, loss = 0.03323328
# Iteration 267, loss = 0.03185413
# Iteration 268, loss = 0.03761213
# Iteration 269, loss = 0.03500397
# Iteration 270, loss = 0.03233928
# Iteration 271, loss = 0.03160452
# Iteration 272, loss = 0.03172669
# Iteration 273, loss = 0.03288486
# Iteration 274, loss = 0.03273276
# Iteration 275, loss = 0.03182832
# Iteration 276, loss = 0.03996127
# Iteration 277, loss = 0.03311420
# Iteration 278, loss = 0.03676529
# Iteration 279, loss = 0.02990919
# Iteration 280, loss = 0.03037979
# Iteration 281, loss = 0.02956457
# Iteration 282, loss = 0.03366712
# Iteration 283, loss = 0.03076294
# Iteration 284, loss = 0.03187139
# Iteration 285, loss = 0.02976177
# Iteration 286, loss = 0.02994120
# Iteration 287, loss = 0.02998928
# Iteration 288, loss = 0.02890386
# Iteration 289, loss = 0.03383100
# Iteration 290, loss = 0.02936648
# Iteration 291, loss = 0.02825491
# Iteration 292, loss = 0.02937584
# Iteration 293, loss = 0.02822881
# Iteration 294, loss = 0.02827878
# Iteration 295, loss = 0.03004677
# Iteration 296, loss = 0.02736174
# Iteration 297, loss = 0.02733179
# Iteration 298, loss = 0.03026525
# Iteration 299, loss = 0.03195002
# Iteration 300, loss = 0.03185230
# Iteration 301, loss = 0.03238051
# Iteration 302, loss = 0.03519840
# Iteration 303, loss = 0.02705861
# Iteration 304, loss = 0.02985027
# Iteration 305, loss = 0.03157504
# Iteration 306, loss = 0.03084558
# Iteration 307, loss = 0.02782220
# Iteration 308, loss = 0.02611026
# Iteration 309, loss = 0.02695507
# Iteration 310, loss = 0.02585044
# Iteration 311, loss = 0.02513643
# Iteration 312, loss = 0.02632248
# Iteration 313, loss = 0.02681645
# Iteration 314, loss = 0.02481287
# Iteration 315, loss = 0.02589079
# Iteration 316, loss = 0.02570308
# Iteration 317, loss = 0.02509835
# Iteration 318, loss = 0.02680493
# Iteration 319, loss = 0.02594037
# Iteration 320, loss = 0.02510442
# Iteration 321, loss = 0.02507546
# Iteration 322, loss = 0.02479316
# Iteration 323, loss = 0.03109435
# Iteration 324, loss = 0.02709224
# Iteration 325, loss = 0.02589182
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#               precision    recall  f1-score   support
#
#            0       0.96      0.32      0.48       234
#            1       0.71      0.99      0.83       390
#
#     accuracy                           0.74       624
#    macro avg       0.84      0.66      0.65       624
# weighted avg       0.80      0.74      0.70       624

# %% [markdown]
# ###Modelo 2

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50, 25), activation='relu', max_iter=500, verbose = True)
mlp.fit(x_train_balanced, y_train_balanced)
y_pred = mlp.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Iteration 1, loss = 0.49078654
# Iteration 2, loss = 0.23553112
# Iteration 3, loss = 0.16343278
# Iteration 4, loss = 0.13815246
# Iteration 5, loss = 0.12272503
# Iteration 6, loss = 0.12205482
# Iteration 7, loss = 0.11538695
# Iteration 8, loss = 0.11259879
# Iteration 9, loss = 0.12141650
# Iteration 10, loss = 0.11177937
# Iteration 11, loss = 0.10647009
# Iteration 12, loss = 0.10323007
# Iteration 13, loss = 0.10245387
# Iteration 14, loss = 0.09755931
# Iteration 15, loss = 0.09952236
# Iteration 16, loss = 0.09888873
# Iteration 17, loss = 0.09463584
# Iteration 18, loss = 0.10311815
# Iteration 19, loss = 0.11110395
# Iteration 20, loss = 0.09773008
# Iteration 21, loss = 0.08826620
# Iteration 22, loss = 0.08570819
# Iteration 23, loss = 0.08865987
# Iteration 24, loss = 0.08956014
# Iteration 25, loss = 0.09482459
# Iteration 26, loss = 0.09570384
# Iteration 27, loss = 0.09092536
# Iteration 28, loss = 0.08063353
# Iteration 29, loss = 0.09062969
# Iteration 30, loss = 0.07922107
# Iteration 31, loss = 0.08269551
# Iteration 32, loss = 0.07536424
# Iteration 33, loss = 0.07373087
# Iteration 34, loss = 0.07600390
# Iteration 35, loss = 0.07340587
# Iteration 36, loss = 0.07231973
# Iteration 37, loss = 0.07072015
# Iteration 38, loss = 0.06830168
# Iteration 39, loss = 0.06733342
# Iteration 40, loss = 0.06748554
# Iteration 41, loss = 0.07020060
# Iteration 42, loss = 0.07673536
# Iteration 43, loss = 0.07902416
# Iteration 44, loss = 0.09052224
# Iteration 45, loss = 0.08477063
# Iteration 46, loss = 0.06537749
# Iteration 47, loss = 0.05876236
# Iteration 48, loss = 0.06498312
# Iteration 49, loss = 0.07108932
# Iteration 50, loss = 0.07122621
# Iteration 51, loss = 0.05788984
# Iteration 52, loss = 0.05527102
# Iteration 53, loss = 0.05716461
# Iteration 54, loss = 0.05934767
# Iteration 55, loss = 0.05431081
# Iteration 56, loss = 0.05953883
# Iteration 57, loss = 0.05050056
# Iteration 58, loss = 0.05495502
# Iteration 59, loss = 0.05815248
# Iteration 60, loss = 0.05021596
# Iteration 61, loss = 0.04885220
# Iteration 62, loss = 0.07108774
# Iteration 63, loss = 0.05777469
# Iteration 64, loss = 0.06042148
# Iteration 65, loss = 0.05781460
# Iteration 66, loss = 0.05329067
# Iteration 67, loss = 0.05254278
# Iteration 68, loss = 0.04662181
# Iteration 69, loss = 0.04605764
# Iteration 70, loss = 0.04969143
# Iteration 71, loss = 0.04505550
# Iteration 72, loss = 0.06221282
# Iteration 73, loss = 0.04495585
# Iteration 74, loss = 0.04050658
# Iteration 75, loss = 0.04388272
# Iteration 76, loss = 0.03985045
# Iteration 77, loss = 0.04142009
# Iteration 78, loss = 0.04144451
# Iteration 79, loss = 0.04404020
# Iteration 80, loss = 0.04120945
# Iteration 81, loss = 0.03585171
# Iteration 82, loss = 0.03793647
# Iteration 83, loss = 0.03947294
# Iteration 84, loss = 0.04927748
# Iteration 85, loss = 0.03666131
# Iteration 86, loss = 0.03519931
# Iteration 87, loss = 0.03550476
# Iteration 88, loss = 0.04251383
# Iteration 89, loss = 0.04378892
# Iteration 90, loss = 0.03552435
# Iteration 91, loss = 0.03211383
# Iteration 92, loss = 0.04298241
# Iteration 93, loss = 0.03914764
# Iteration 94, loss = 0.03292824
# Iteration 95, loss = 0.03354051
# Iteration 96, loss = 0.03609844
# Iteration 97, loss = 0.03290229
# Iteration 98, loss = 0.02845912
# Iteration 99, loss = 0.02988611
# Iteration 100, loss = 0.03197533
# Iteration 101, loss = 0.02881643
# Iteration 102, loss = 0.02623077
# Iteration 103, loss = 0.02715997
# Iteration 104, loss = 0.02745148
# Iteration 105, loss = 0.02893242
# Iteration 106, loss = 0.02491300
# Iteration 107, loss = 0.04133815
# Iteration 108, loss = 0.03041845
# Iteration 109, loss = 0.02818435
# Iteration 110, loss = 0.02623094
# Iteration 111, loss = 0.02463373
# Iteration 112, loss = 0.02413540
# Iteration 113, loss = 0.02288280
# Iteration 114, loss = 0.05103587
# Iteration 115, loss = 0.03082466
# Iteration 116, loss = 0.02477532
# Iteration 117, loss = 0.02387650
# Iteration 118, loss = 0.02392519
# Iteration 119, loss = 0.03740929
# Iteration 120, loss = 0.02500237
# Iteration 121, loss = 0.02008640
# Iteration 122, loss = 0.01884788
# Iteration 123, loss = 0.02893036
# Iteration 124, loss = 0.01990290
# Iteration 125, loss = 0.02740986
# Iteration 126, loss = 0.02148471
# Iteration 127, loss = 0.01865727
# Iteration 128, loss = 0.01734387
# Iteration 129, loss = 0.02660317
# Iteration 130, loss = 0.04706401
# Iteration 131, loss = 0.01823369
# Iteration 132, loss = 0.02511393
# Iteration 133, loss = 0.01915878
# Iteration 134, loss = 0.01659818
# Iteration 135, loss = 0.01625266
# Iteration 136, loss = 0.02889972
# Iteration 137, loss = 0.03152397
# Iteration 138, loss = 0.01531761
# Iteration 139, loss = 0.01544757
# Iteration 140, loss = 0.01684758
# Iteration 141, loss = 0.02105176
# Iteration 142, loss = 0.02300308
# Iteration 143, loss = 0.01421576
# Iteration 144, loss = 0.01411489
# Iteration 145, loss = 0.01964201
# Iteration 146, loss = 0.01462797
# Iteration 147, loss = 0.01332455
# Iteration 148, loss = 0.01813765
# Iteration 149, loss = 0.01629423
# Iteration 150, loss = 0.01741304
# Iteration 151, loss = 0.01416208
# Iteration 152, loss = 0.01197764
# Iteration 153, loss = 0.01507208
# Iteration 154, loss = 0.01388576
# Iteration 155, loss = 0.01219263
# Iteration 156, loss = 0.01649359
# Iteration 157, loss = 0.01235008
# Iteration 158, loss = 0.00922358
# Iteration 159, loss = 0.00975132
# Iteration 160, loss = 0.02000794
# Iteration 161, loss = 0.04666691
# Iteration 162, loss = 0.04445454
# Iteration 163, loss = 0.02895776
# Iteration 164, loss = 0.01455220
# Iteration 165, loss = 0.01032284
# Iteration 166, loss = 0.01282186
# Iteration 167, loss = 0.00990477
# Iteration 168, loss = 0.01362140
# Iteration 169, loss = 0.00952277
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#               precision    recall  f1-score   support
#
#            0       0.94      0.40      0.56       234
#            1       0.73      0.98      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.84      0.69      0.70       624
# weighted avg       0.81      0.76      0.73       624

# %% [markdown]
# ### Modelo 3

# %%
mlp = MLPClassifier(hidden_layer_sizes=(50, 25, 13), activation='tanh', max_iter=500, verbose = True)
mlp.fit(x_train_balanced, y_train_balanced)
y_pred = mlp.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
# Iteration 1, loss = 0.51607151
# Iteration 2, loss = 0.25613901
# Iteration 3, loss = 0.18501909
# Iteration 4, loss = 0.15356598
# Iteration 5, loss = 0.13647092
# Iteration 6, loss = 0.12161011
# Iteration 7, loss = 0.12117365
# Iteration 8, loss = 0.11264876
# Iteration 9, loss = 0.14113042
# Iteration 10, loss = 0.10748791
# Iteration 11, loss = 0.11685996
# Iteration 12, loss = 0.10187794
# Iteration 13, loss = 0.09760666
# Iteration 14, loss = 0.09307357
# Iteration 15, loss = 0.09033339
# Iteration 16, loss = 0.09738205
# Iteration 17, loss = 0.09042392
# Iteration 18, loss = 0.08939183
# Iteration 19, loss = 0.09523366
# Iteration 20, loss = 0.08755649
# Iteration 21, loss = 0.08151276
# Iteration 22, loss = 0.08363506
# Iteration 23, loss = 0.08159749
# Iteration 24, loss = 0.07263148
# Iteration 25, loss = 0.07148891
# Iteration 26, loss = 0.07509087
# Iteration 27, loss = 0.06578545
# Iteration 28, loss = 0.06863482
# Iteration 29, loss = 0.06690132
# Iteration 30, loss = 0.07143136
# Iteration 31, loss = 0.07483224
# Iteration 32, loss = 0.06790299
# Iteration 33, loss = 0.06206135
# Iteration 34, loss = 0.06551158
# Iteration 35, loss = 0.06231430
# Iteration 36, loss = 0.06180111
# Iteration 37, loss = 0.07025365
# Iteration 38, loss = 0.05251911
# Iteration 39, loss = 0.05039285
# Iteration 40, loss = 0.04859054
# Iteration 41, loss = 0.06007898
# Iteration 42, loss = 0.07141503
# Iteration 43, loss = 0.05165448
# Iteration 44, loss = 0.05192982
# Iteration 45, loss = 0.04844222
# Iteration 46, loss = 0.05635973
# Iteration 47, loss = 0.04802913
# Iteration 48, loss = 0.04777233
# Iteration 49, loss = 0.04050951
# Iteration 50, loss = 0.04015394
# Iteration 51, loss = 0.03961814
# Iteration 52, loss = 0.06874073
# Iteration 53, loss = 0.06652283
# Iteration 54, loss = 0.04909272
# Iteration 55, loss = 0.04500969
# Iteration 56, loss = 0.04723316
# Iteration 57, loss = 0.04448948
# Iteration 58, loss = 0.03690598
# Iteration 59, loss = 0.04663863
# Iteration 60, loss = 0.04301888
# Iteration 61, loss = 0.03897493
# Iteration 62, loss = 0.03940244
# Iteration 63, loss = 0.03404466
# Iteration 64, loss = 0.04104347
# Iteration 65, loss = 0.04152987
# Iteration 66, loss = 0.05140158
# Iteration 67, loss = 0.04178787
# Iteration 68, loss = 0.04385920
# Iteration 69, loss = 0.03376042
# Iteration 70, loss = 0.02975112
# Iteration 71, loss = 0.03521985
# Iteration 72, loss = 0.05068024
# Iteration 73, loss = 0.04031824
# Iteration 74, loss = 0.02636280
# Iteration 75, loss = 0.02700986
# Iteration 76, loss = 0.03118170
# Iteration 77, loss = 0.02612819
# Iteration 78, loss = 0.02548841
# Iteration 79, loss = 0.03982046
# Iteration 80, loss = 0.04581621
# Iteration 81, loss = 0.02898577
# Iteration 82, loss = 0.04145079
# Iteration 83, loss = 0.03461627
# Iteration 84, loss = 0.02822544
# Iteration 85, loss = 0.02360313
# Iteration 86, loss = 0.02896427
# Iteration 87, loss = 0.02397825
# Iteration 88, loss = 0.03621629
# Iteration 89, loss = 0.02288881
# Iteration 90, loss = 0.03343590
# Iteration 91, loss = 0.02143309
# Iteration 92, loss = 0.02202250
# Iteration 93, loss = 0.02584189
# Iteration 94, loss = 0.03521362
# Iteration 95, loss = 0.01993438
# Iteration 96, loss = 0.02004702
# Iteration 97, loss = 0.02637193
# Iteration 98, loss = 0.04184886
# Iteration 99, loss = 0.06823875
# Iteration 100, loss = 0.02284800
# Iteration 101, loss = 0.02644300
# Iteration 102, loss = 0.01697170
# Iteration 103, loss = 0.02112888
# Iteration 104, loss = 0.01489437
# Iteration 105, loss = 0.01495842
# Iteration 106, loss = 0.02043656
# Iteration 107, loss = 0.01593897
# Iteration 108, loss = 0.01727787
# Iteration 109, loss = 0.02315900
# Iteration 110, loss = 0.02853236
# Iteration 111, loss = 0.01803642
# Iteration 112, loss = 0.01400387
# Iteration 113, loss = 0.03423359
# Iteration 114, loss = 0.02471199
# Iteration 115, loss = 0.01605645
# Iteration 116, loss = 0.05386247
# Iteration 117, loss = 0.04252270
# Iteration 118, loss = 0.01336936
# Iteration 119, loss = 0.01281417
# Iteration 120, loss = 0.01259250
# Iteration 121, loss = 0.01879075
# Iteration 122, loss = 0.01204209
# Iteration 123, loss = 0.01018200
# Iteration 124, loss = 0.01158268
# Iteration 125, loss = 0.01661033
# Iteration 126, loss = 0.01253366
# Iteration 127, loss = 0.01334177
# Iteration 128, loss = 0.02264403
# Iteration 129, loss = 0.02081680
# Iteration 130, loss = 0.02349118
# Iteration 131, loss = 0.01660554
# Iteration 132, loss = 0.00809290
# Iteration 133, loss = 0.00859987
# Iteration 134, loss = 0.00984138
# Iteration 135, loss = 0.00949252
# Iteration 136, loss = 0.01246722
# Iteration 137, loss = 0.00916396
# Iteration 138, loss = 0.00719823
# Iteration 139, loss = 0.00799280
# Iteration 140, loss = 0.00671010
# Iteration 141, loss = 0.00873183
# Iteration 142, loss = 0.00901550
# Iteration 143, loss = 0.01310867
# Iteration 144, loss = 0.02859487
# Iteration 145, loss = 0.05482186
# Iteration 146, loss = 0.02180239
# Iteration 147, loss = 0.01272798
# Iteration 148, loss = 0.00612410
# Iteration 149, loss = 0.01030449
# Iteration 150, loss = 0.00491944
# Iteration 151, loss = 0.01941597
# Iteration 152, loss = 0.01903420
# Iteration 153, loss = 0.01074102
# Iteration 154, loss = 0.00725067
# Iteration 155, loss = 0.01909465
# Iteration 156, loss = 0.00681780
# Iteration 157, loss = 0.00362178
# Iteration 158, loss = 0.00824595
# Iteration 159, loss = 0.02120569
# Iteration 160, loss = 0.01805273
# Iteration 161, loss = 0.01120247
# Iteration 162, loss = 0.00748805
# Iteration 163, loss = 0.00289785
# Iteration 164, loss = 0.00746857
# Iteration 165, loss = 0.01049432
# Iteration 166, loss = 0.00354367
# Iteration 167, loss = 0.00399046
# Iteration 168, loss = 0.00488230
# Iteration 169, loss = 0.00323578
# Iteration 170, loss = 0.00951348
# Iteration 171, loss = 0.06226600
# Iteration 172, loss = 0.01841360
# Iteration 173, loss = 0.00535981
# Iteration 174, loss = 0.00397042
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#               precision    recall  f1-score   support
#
#            0       0.93      0.41      0.57       234
#            1       0.74      0.98      0.84       390
#
#     accuracy                           0.77       624
#    macro avg       0.83      0.70      0.71       624
# weighted avg       0.81      0.77      0.74       624

# %% [markdown]
# ### Resultados observados

# %% [markdown]
# O Modelo 3 apresenta um melhor equilíbrio entre precisão, recall e acurácia geral, mostrando maior eficácia na classificação das duas classes do conjunto de dados. Comparado com o Modelo 1 e o Modelo 2, os Modelos 2 e 3 possuem um melhor recall para a classe 0 (ausência de pneumonia), indicando que são mais eficientes em identificar corretamente os casos negativos. Para a classe 1 (presença de pneumonia), todos os modelos têm valores de recall semelhantes, sugerindo que todos são eficazes em identificar casos de pneumonia. No entanto, o Modelo 1 se destaca por ter o maior recall para a classe 1.
#
# A arquitetura da rede neural e a função de ativação desempenham um papel fundamental no desempenho do modelo. Modelos mais complexos, com mais camadas e neurônios (como os Modelos 2 e 3), possuem maior capacidade de aprendizado, permitindo que capturem representações mais complexas dos dados, mas também podem aumentar o risco de overfitting.
#
# Em termos de escolha do melhor modelo, é importante considerar que o modelo ideal deve ser capaz de identificar todos os casos de pneumonia, mesmo que isso resulte em mais falsos positivos. A capacidade de detectar todos os casos de pneumonia é crucial, pois o custo de não detectar um caso de pneumonia (falso negativo) pode ser mais alto do que o custo de ter alguns falsos positivos.

# %% [markdown]
# ## Comparando o melhor modelo com um Ensemble

# %%
rf = RandomForestClassifier()

hiperpametros = {
    'n_estimators': [50, 100, 200],
    'max_depth': [1, 5, 10],
}

rf_gridsearch = GridSearchCV(rf, hiperpametros, cv=5, scoring='accuracy')
rf_gridsearch.fit(x_train_balanced, y_train_balanced)
rf_best = rf_gridsearch.best_estimator_
rf_predict = rf_best.predict(x_test)

print("Random Forest:")
print("Melhores hiperâmetros:", rf_gridsearch.best_params_)

accuracy = accuracy_score(y_test, rf_predict)
precision = precision_score(y_test, rf_predict)
recall = recall_score(y_test, rf_predict)
f1 = f1_score(y_test, rf_predict)

evaluation = f"Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1}"

print(evaluation)
# Out:
# Random Forest:
# Melhores hiperâmetros: {'max_depth': 10, 'n_estimators': 100}
# Accuracy: 0.8076923076923077
# Precision: 0.7777777777777778
# Recall: 0.9692307692307692
# F1 Score: 0.863013698630137

# %% [markdown]
# ### Comparação do Random Forest com o melhor MLP

# %% [markdown]
# O modelo Random Forest superou o Modelo 3 em vários aspectos importantes. Com uma acurácia de 80%, em comparação com 77% do MLP, o Random Forest demonstra maior precisão geral na classificação. Além disso, apresenta um recall de 97%, evidenciando uma boa habilidade em identificar corretamente a classe positiva (classe 1), ao contrário do MLP, cujo recall é desigual entre as classes.
#
# O F1-Score do Random Forest também é mais equilibrado e superior ao do MLP, que varia significativamente entre as classes. Isso indica que o Random Forest oferece uma performance mais robusta e equilibrada, destacando-se tanto em termos de recall quanto de F1-Score. Essas métricas sugerem uma vantagem geral em eficácia e balanceamento no desempenho do Random Forest.
#
# Comparando os dois modelos, podemos observar que o Random Forest é mais eficiente para este conjunto de dados. Entretanto, o MLP, uma rede neural artificial, pode se destacar em dados mais complexos, mas é sensível aos hiperparâmetros, o que pode impactar significativamente seu desempenho. Além disso, o MLP é mais propenso ao overfitting, o que deve ser cuidadosamente monitorado.
